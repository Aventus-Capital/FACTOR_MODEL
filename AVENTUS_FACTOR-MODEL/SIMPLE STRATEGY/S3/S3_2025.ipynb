# %%
import pandas as pd

# %%
df1 = pd.read_excel("New_S3.xlsx")
df1.tail()
# Out:
#    Sr.No.  Accord Code                     Company Name  Gross_Plus_CWIP  \
# 2       3       284634           Krishana Phoschem Ltd.         491.9800
# 3       4       287490                SBFC Finance Ltd.         343.6140
# 4       5       219236       Thangamayil Jewellery Ltd.         259.0200
# 5       6       288476  Utkarsh Small Finance Bank Ltd.         549.0076
# 6       7       315297       Utssav CZ Gold Jewels Ltd.          11.5702
#
#    Gross_Plus_CWIP1  Working Capital  Working Capital1  PL_Net Sales  \
# 2          454.1816         116.2133           56.5294      923.8977
# 3          327.8530         433.6840          487.9340     1018.6400
# 4          207.2100         457.4900          405.2000     3826.7800
# 5          483.9400           0.0000            0.0000     3178.4115
# 6            9.7631          28.1533           21.8628      340.1956
#
#    PL_Net Sales1  Incremental CAPEX  ...  CD_BSE Code  CD_NSE Symbol  \
# 2       322.8176           6.288413  ...          NaN       KRISHANA
# 3       732.8120           5.514155  ...     543959.0           SBFC
# 4      3152.5500           7.684321  ...     533158.0     THANGAMAYL
# 5      2504.9798           9.662093  ...     543942.0     UTKARSHBNK
# 6       238.1861           1.771502  ...          NaN         UTSSAV
#
#    FH_Market Capitalization  CGross_Plus_CWIP_CONS  CWorking Capital_CONS  \
# 2               1508.902578                      S                      S
# 3               8771.267687                      C                      C
# 4               3535.918400                      S                      S
# 5               5152.057845                      S                      S
# 6                  0.000000                      S                      S
#
#    Clong term borrowing_CONS  CONS_PL_1 CONS_PL_2  CONS_BS_2 CONS_FH_1
# 2                          S          S         S          S         S
# 3                          C          C         C          C         C
# 4                          S          S         S          S         S
# 5                          S          S         S          S         S
# 6                          S          S         S          S         S
#
# [5 rows x 26 columns]

# %%
#LOWER THE BETTER SO * -1 
mean_value = df1['Incremental CAPEX'].mean()
std_dev = df1['Incremental CAPEX'].std()
df1['ZSCORE_CAPEX'] = ((df1['Incremental CAPEX']-mean_value) / std_dev) * (-1)


#LOWER THE BETTER SO * -1
mean_value = df1['Incremental WC'].mean()
std_dev = df1['Incremental WC'].std()
df1['ZSCORE_WC'] = (df1['Incremental WC']-mean_value) / std_dev * (-1)


mean_value = df1['Sales Growth'].mean()
std_dev = df1['Sales Growth'].std()
df1['ZSCORE_SALES'] = (df1['Sales Growth']-mean_value) / std_dev


mean_value = df1['FH_Market Capitalization'].mean()
std_dev = df1['FH_Market Capitalization'].std()
df1['ZSCORE_MCAP'] = (df1['FH_Market Capitalization']-mean_value) / std_dev


df1.head()
# Out:
#    Sr.No.  Accord Code                  Company Name  Gross_Plus_CWIP  \
# 0       1       287810  ESAF Small Finance Bank Ltd.         404.4508
# 1       2       290269      Indiamart Intermesh Ltd.         644.9330
# 2       3       284634        Krishana Phoschem Ltd.         491.9800
# 3       4       287490             SBFC Finance Ltd.         343.6140
# 4       5       219236    Thangamayil Jewellery Ltd.         259.0200
#
#    Gross_Plus_CWIP1  Working Capital  Working Capital1  PL_Net Sales  \
# 0          335.2450           0.0000            0.0000     3818.4268
# 1          629.9660        1302.6100         1507.3070     1196.7750
# 2          454.1816         116.2133           56.5294      923.8977
# 3          327.8530         433.6840          487.9340     1018.6400
# 4          207.2100         457.4900          405.2000     3826.7800
#
#    PL_Net Sales1  Incremental CAPEX  ...  CWorking Capital_CONS  \
# 0      2853.5980           7.172858  ...                      S
# 1       985.3990           7.080747  ...                      C
# 2       322.8176           6.288413  ...                      S
# 3       732.8120           5.514155  ...                      C
# 4      3152.5500           7.684321  ...                      S
#
#    Clong term borrowing_CONS  CONS_PL_1  CONS_PL_2  CONS_BS_2  CONS_FH_1  \
# 0                          S          S          S          S          S
# 1                          C          C          C          C          C
# 2                          S          S          S          S          S
# 3                          C          C          C          C          C
# 4                          S          S          S          S          S
#
#    ZSCORE_CAPEX ZSCORE_WC  ZSCORE_SALES ZSCORE_MCAP
# 0     -0.295547 -0.344502     -0.325046   -0.477874
# 1     -0.257706  2.194751     -0.533544    1.939336
# 2      0.067796 -0.604863      2.245504   -0.714808
# 3      0.385872  0.153172     -0.237443    0.628226
# 4     -0.505663 -0.547860     -0.534624   -0.339951
#
# [5 rows x 30 columns]

# %%
df2 = pd.read_excel("TRENDLYNE_230425.xlsx")
df2.head()
# Out:
#             Stock Name   NSE Code  BSE Code  Stock Code          ISIN  \
# 0      20 Microns Ltd.  20MICRONS  533022.0   20MICRONS  INE144J01027
# 1     360 ONE Gold ETF    GOLD360  544375.0     GOLD360  INF579M01BB5
# 2   360 ONE Silver ETF  SILVER360  544389.0   SILVER360  INF579M01BC3
# 3     360 One Wam Ltd.     360ONE  542772.0      360ONE  INE466L01038
# 4  3B BlackBio Dx Ltd.        NaN  532067.0  3BBLACKBIO  INE994E01018
#
#      Industry Name  Current Price  Current Price.1  Market Capitalization  \
# 0    Coal & Mining         227.25           227.25                 801.89
# 1           Others          95.45            95.45                    NaN
# 2           Others          99.20            99.20                    NaN
# 3  Capital Markets        1057.00          1057.00               41613.87
# 4    Agrochemicals        1784.05          1784.05                1531.20
#
#    PE TTM Price to Earnings  ... Sector Return on Equity ROE  \
# 0                     13.19  ...                       23.96
# 1                       NaN  ...                         NaN
# 2                       NaN  ...                         NaN
# 3                     41.27  ...                       17.25
# 4                     31.87  ...                       14.53
#
#    Industry Return on Equity ROE  RoA Annual %  Sector Return on Assets  \
# 0                          38.63          9.50                    10.88
# 1                            NaN           NaN                      NaN
# 2                            NaN           NaN                      NaN
# 3                          23.88          5.31                     2.86
# 4                          17.06         12.93                     9.90
#
#    Industry Return on Assets  Piotroski Score                 sector_name  \
# 0                      17.60              7.0             Metals & Mining
# 1                        NaN              NaN                      Others
# 2                        NaN              NaN                      Others
# 3                       8.70              3.0         Banking and Finance
# 4                      12.59              7.0  Chemicals & Petrochemicals
#
#    Industry Name.1  Latest financial result  Result Announced Date
# 0    Coal & Mining               2024-12-31             2025-01-22
# 1           Others                      NaT                    NaT
# 2           Others                      NaT                    NaT
# 3  Capital Markets               2024-12-31             2025-04-23
# 4    Agrochemicals               2024-12-31             2025-02-13
#
# [5 rows x 37 columns]

# %%
df1['CD_BSE Code'] = pd.to_numeric(df1['CD_BSE Code'], errors='coerce')
df2['BSE Code'] = pd.to_numeric(df2['BSE Code'], errors='coerce')

df1['CD_NSE Symbol'] = df1['CD_NSE Symbol'].astype(str).str.upper()
df2['NSE Code'] = df2['NSE Code'].astype(str).str.upper()

# Deduplicate df2 to avoid one-to-many joins
df2_bse_dedup = df2.drop_duplicates(subset='BSE Code')
df2_nse_dedup = df2.drop_duplicates(subset='NSE Code')

# Step 1: Join on BSE Code
merged_bse = df1.merge(df2_bse_dedup, how='left', left_on='CD_BSE Code', right_on='BSE Code', indicator=True)

# Step 2: Filter unmatched and join them on NSE Code
unmatched = merged_bse[merged_bse['_merge'] == 'left_only'].copy()
matched = merged_bse[merged_bse['_merge'] == 'both'].copy()

# Remove merged df2 columns from unmatched before re-joining
unmatched_clean = unmatched[df1.columns]

# Join unmatched on NSE Code
merged_nse = unmatched_clean.merge(df2_nse_dedup, how='left', left_on='CD_NSE Symbol', right_on='NSE Code')

# Combine both
final_merged = pd.concat([matched.drop(columns=['_merge']), merged_nse], ignore_index=True)

# Optional: Save to Excel
# final_merged.to_csv("visual_tp.csv",index=False)
final_merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 67 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Sr.No.                                           7 non-null      int64
#  1   Accord Code                                      7 non-null      int64
#  2   Company Name                                     7 non-null      object
#  3   Gross_Plus_CWIP                                  7 non-null      float64
#  4   Gross_Plus_CWIP1                                 7 non-null      float64
#  5   Working Capital                                  7 non-null      float64
#  6   Working Capital1                                 7 non-null      float64
#  7   PL_Net Sales                                     7 non-null      float64
#  8   PL_Net Sales1                                    7 non-null      float64
#  9   Incremental CAPEX                                7 non-null      float64
#  10  Incremental WC                                   7 non-null      float64
#  11  Sales Growth                                     7 non-null      float64
#  12  BS_Share Capital                                 7 non-null      float64
#  13  BS_Share Capital1                                7 non-null      float64
#  14  long term borrowing                              7 non-null      float64
#  15  long term borrowing1                             7 non-null      float64
#  16  CD_BSE Code                                      5 non-null      float64
#  17  CD_NSE Symbol                                    7 non-null      object
#  18  FH_Market Capitalization                         7 non-null      float64
#  19  CGross_Plus_CWIP_CONS                            7 non-null      object
#  20  CWorking Capital_CONS                            7 non-null      object
#  21  Clong term borrowing_CONS                        7 non-null      object
#  22  CONS_PL_1                                        7 non-null      object
#  23  CONS_PL_2                                        7 non-null      object
#  24  CONS_BS_2                                        7 non-null      object
#  25  CONS_FH_1                                        7 non-null      object
#  26  ZSCORE_CAPEX                                     7 non-null      float64
#  27  ZSCORE_WC                                        7 non-null      float64
#  28  ZSCORE_SALES                                     7 non-null      float64
#  29  ZSCORE_MCAP                                      7 non-null      float64
#  30  Stock Name                                       7 non-null      object
#  31  NSE Code                                         7 non-null      object
#  32  BSE Code                                         5 non-null      float64
#  33  Stock Code                                       7 non-null      object
#  34  ISIN                                             7 non-null      object
#  35  Industry Name                                    7 non-null      object
#  36  Current Price                                    7 non-null      float64
#  37  Current Price.1                                  7 non-null      float64
#  38  Market Capitalization                            7 non-null      float64
#  39  PE TTM Price to Earnings                         7 non-null      float64
#  40  Forecaster Estimates 1Y forward PE               7 non-null      object
#  41  PE 3Yr Average                                   2 non-null      float64
#  42  PE 5Yr Average                                   2 non-null      float64
#  43  %Days traded below current PE Price to Earnings  4 non-null      float64
#  44  Sector PE TTM                                    7 non-null      float64
#  45  Industry PE TTM                                  7 non-null      float64
#  46  PEG TTM PE to Growth                             4 non-null      float64
#  47  Forecaster Estimates 1Y forward PEG              7 non-null      object
#  48  Sector PEG TTM                                   7 non-null      float64
#  49  Industry PEG TTM                                 7 non-null      float64
#  50  Price to Book Value                              7 non-null      float64
#  51  %Days traded below current Price to Book Value   5 non-null      float64
#  52  Sector Price to Book TTM                         7 non-null      float64
#  53  Industry Price to Book TTM                       7 non-null      float64
#  54  Basic EPS TTM                                    7 non-null      float64
#  55  EPS TTM Growth %                                 4 non-null      float64
#  56  ROE Annual %                                     7 non-null      float64
#  57  Sector Return on Equity ROE                      7 non-null      float64
#  58  Industry Return on Equity ROE                    7 non-null      float64
#  59  RoA Annual %                                     7 non-null      float64
#  60  Sector Return on Assets                          7 non-null      float64
#  61  Industry Return on Assets                        7 non-null      float64
#  62  Piotroski Score                                  7 non-null      float64
#  63  sector_name                                      7 non-null      object
#  64  Industry Name.1                                  7 non-null      object
#  65  Latest financial result                          7 non-null      datetime64[ns]
#  66  Result Announced Date                            7 non-null      datetime64[ns]
# dtypes: datetime64[ns](2), float64(45), int64(2), object(18)
# memory usage: 3.8+ KB

# %%
# Set the DATE column as the index for rolling operation
column_list = final_merged['Stock Code'].tolist()

vol_df = pd.read_csv("C:/Users/meets/AVENTUS_FACTOR-MODEL/SIMPLE STRATEGY/mega_datevol_final.csv")
vol_df['DATE'] = pd.to_datetime(vol_df['DATE'])

vol_df.set_index('DATE', inplace=True)

# Filter column_list to only include columns present in vol_df
valid_columns = [col for col in column_list if col in vol_df.columns]

# Apply rolling mean with a window of 20 days and min_periods=1
rolling_means = vol_df[valid_columns].rolling(window=20, min_periods=1).mean()

# Extract the rolling average values as of 2009-04-01
rolling_avg_at_date = rolling_means.loc[pd.Timestamp('2025-03-03')]

# Store the result in a DataFrame
result_df_updated = pd.DataFrame({
    'STOCK NAME': rolling_avg_at_date.index,
    'MA': rolling_avg_at_date.values
})

# result_df_updated.info()

merged_df_1 = pd.merge(final_merged, result_df_updated, how='inner', left_on='Stock Code', right_on='STOCK NAME')
merged_df_1.info()

merged_df = merged_df_1[(merged_df_1["Market Capitalization"] >= 1000) & (merged_df_1["MA"] >= 10000)]

# Show the number of rows removed and preview the cleaned data
rows_removed = len(merged_df_1) - len(merged_df)
merged_df.head(), rows_removed
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 69 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Sr.No.                                           5 non-null      int64
#  1   Accord Code                                      5 non-null      int64
#  2   Company Name                                     5 non-null      object
#  3   Gross_Plus_CWIP                                  5 non-null      float64
#  4   Gross_Plus_CWIP1                                 5 non-null      float64
#  5   Working Capital                                  5 non-null      float64
#  6   Working Capital1                                 5 non-null      float64
#  7   PL_Net Sales                                     5 non-null      float64
#  8   PL_Net Sales1                                    5 non-null      float64
#  9   Incremental CAPEX                                5 non-null      float64
#  10  Incremental WC                                   5 non-null      float64
#  11  Sales Growth                                     5 non-null      float64
#  12  BS_Share Capital                                 5 non-null      float64
#  13  BS_Share Capital1                                5 non-null      float64
#  14  long term borrowing                              5 non-null      float64
#  15  long term borrowing1                             5 non-null      float64
#  16  CD_BSE Code                                      5 non-null      float64
#  17  CD_NSE Symbol                                    5 non-null      object
#  18  FH_Market Capitalization                         5 non-null      float64
#  19  CGross_Plus_CWIP_CONS                            5 non-null      object
#  20  CWorking Capital_CONS                            5 non-null      object
#  21  Clong term borrowing_CONS                        5 non-null      object
#  22  CONS_PL_1                                        5 non-null      object
#  23  CONS_PL_2                                        5 non-null      object
#  24  CONS_BS_2                                        5 non-null      object
#  25  CONS_FH_1                                        5 non-null      object
#  26  ZSCORE_CAPEX                                     5 non-null      float64
#  27  ZSCORE_WC                                        5 non-null      float64
#  28  ZSCORE_SALES                                     5 non-null      float64
#  29  ZSCORE_MCAP                                      5 non-null      float64
#  30  Stock Name                                       5 non-null      object
#  31  NSE Code                                         5 non-null      object
#  32  BSE Code                                         5 non-null      float64
#  33  Stock Code                                       5 non-null      object
#  34  ISIN                                             5 non-null      object
#  35  Industry Name                                    5 non-null      object
#  36  Current Price                                    5 non-null      float64
#  37  Current Price.1                                  5 non-null      float64
#  38  Market Capitalization                            5 non-null      float64
#  39  PE TTM Price to Earnings                         5 non-null      float64
#  40  Forecaster Estimates 1Y forward PE               5 non-null      object
#  41  PE 3Yr Average                                   2 non-null      float64
#  42  PE 5Yr Average                                   2 non-null      float64
#  43  %Days traded below current PE Price to Earnings  4 non-null      float64
#  44  Sector PE TTM                                    5 non-null      float64
#  45  Industry PE TTM                                  5 non-null      float64
#  46  PEG TTM PE to Growth                             4 non-null      float64
#  47  Forecaster Estimates 1Y forward PEG              5 non-null      object
#  48  Sector PEG TTM                                   5 non-null      float64
#  49  Industry PEG TTM                                 5 non-null      float64
#  50  Price to Book Value                              5 non-null      float64
#  51  %Days traded below current Price to Book Value   5 non-null      float64
#  52  Sector Price to Book TTM                         5 non-null      float64
#  53  Industry Price to Book TTM                       5 non-null      float64
#  54  Basic EPS TTM                                    5 non-null      float64
#  55  EPS TTM Growth %                                 4 non-null      float64
#  56  ROE Annual %                                     5 non-null      float64
#  57  Sector Return on Equity ROE                      5 non-null      float64
#  58  Industry Return on Equity ROE                    5 non-null      float64
#  59  RoA Annual %                                     5 non-null      float64
#  60  Sector Return on Assets                          5 non-null      float64
#  61  Industry Return on Assets                        5 non-null      float64
#  62  Piotroski Score                                  5 non-null      float64
#  63  sector_name                                      5 non-null      object
#  64  Industry Name.1                                  5 non-null      object
#  65  Latest financial result                          5 non-null      datetime64[ns]
#  66  Result Announced Date                            5 non-null      datetime64[ns]
#  67  STOCK NAME                                       5 non-null      object
#  68  MA                                               5 non-null      float64
# dtypes: datetime64[ns](2), float64(46), int64(2), object(19)
# memory usage: 2.8+ KB
# (   Sr.No.  Accord Code                     Company Name  Gross_Plus_CWIP  \
#  0       1       287810     ESAF Small Finance Bank Ltd.         404.4508
#  1       2       290269         Indiamart Intermesh Ltd.         644.9330
#  2       4       287490                SBFC Finance Ltd.         343.6140
#  3       5       219236       Thangamayil Jewellery Ltd.         259.0200
#  4       6       288476  Utkarsh Small Finance Bank Ltd.         549.0076
#
#     Gross_Plus_CWIP1  Working Capital  Working Capital1  PL_Net Sales  \
#  0           335.245            0.000             0.000     3818.4268
#  1           629.966         1302.610          1507.307     1196.7750
#  2           327.853          433.684           487.934     1018.6400
#  3           207.210          457.490           405.200     3826.7800
#  4           483.940            0.000             0.000     3178.4115
#
#     PL_Net Sales1  Incremental CAPEX  ...  RoA Annual %  \
#  0      2853.5980           7.172858  ...          1.63
#  1       985.3990           7.080747  ...          9.68
#  2       732.8120           5.514155  ...          3.35
#  3      3152.5500           7.684321  ...          8.32
#  4      2504.9798           9.662093  ...          2.08
#
#     Sector Return on Assets  Industry Return on Assets  Piotroski Score  \
#  0                     2.86                       2.51              6.0
#  1                     9.05                       1.75              7.0
#  2                     2.86                       4.26              4.0
#  3                    10.65                       9.76              6.0
#  4                     2.86                       2.51              4.0
#
#                         sector_name              Industry Name.1  \
#  0              Banking and Finance    Microfinance Institutions
#  1                        Retailing  Internet & Catalogue Retail
#  2              Banking and Finance    Finance (including NBFCs)
#  3  Textiles Apparels & Accessories             Gems & Jewellery
#  4              Banking and Finance    Microfinance Institutions
#
#     Latest financial result Result Announced Date  STOCK NAME          MA
#  0               2024-12-31            2025-02-10     ESAFSFB   680407.05
#  1               2024-12-31            2025-01-21   INDIAMART   145956.85
#  2               2024-12-31            2025-04-26        SBFC  1704155.45
#  3               2024-12-31            2025-02-05  THANGAMAYL   151419.25
#  4               2024-12-31            2025-02-14  UTKARSHBNK  2167450.50
#
#  [5 rows x 69 columns],
#  0)

# %%
# merged_df = pd.merge(df1, df2, how='inner', left_on='Company Name', right_on='Stock Name')
# merged_df.head()

# %%
df3 = pd.read_excel("C:/Users/meets/AVENTUS_FACTOR-MODEL/SIMPLE STRATEGY/L Valuation Data.xlsx")

final_merged_df = pd.merge(merged_df, df3, how='inner', left_on='Company Name', right_on='Company Name')
final_merged_df.head()

mean_value = final_merged_df['FR_Adjusted PE (x)'].mean()
std_dev = final_merged_df['FR_Adjusted PE (x)'].std()
final_merged_df['ZSCORE_PE'] = (final_merged_df['FR_Adjusted PE (x)']-mean_value) / std_dev

mean_value = final_merged_df['FR_EV/EBITDA(x)'].mean()
std_dev = final_merged_df['FR_EV/EBITDA(x)'].std()
final_merged_df['ZSCORE_EVEBITDA'] = (final_merged_df['FR_EV/EBITDA(x)']-mean_value) / std_dev

final_merged_df['ZSCORE_FINAL'] = ((1/5) * final_merged_df['ZSCORE_CAPEX']) + ((1/5) * final_merged_df['ZSCORE_WC']) + ((1/5) * final_merged_df['ZSCORE_SALES']) + (0.20 * final_merged_df['ZSCORE_MCAP']) + (0.10 * final_merged_df['ZSCORE_PE']) + (0.10 * final_merged_df['ZSCORE_EVEBITDA'])
# final_merged_df['ZSCORE_FINAL'] = (1 * final_merged_df['ZSCORE_CAPEX'])



final_merged_df = final_merged_df[final_merged_df["ZSCORE_FINAL"]>0]

# final_merged_df['PORTFOLIO_WEIGHTS'] = final_merged_df["ZSCORE_FINAL"]/final_merged_df["ZSCORE_FINAL"].sum()

column_list = final_merged_df['Stock Code'].tolist()
print(column_list)

final_merged_df.head()

final_merged_df.to_csv("final_s32025.csv")
# Out:
# ['INDIAMART', 'SBFC']

# %%
df = pd.read_csv("C:/Users/meets/AVENTUS_FACTOR-MODEL/SIMPLE STRATEGY/mega_dateclose_final.csv")
columns_to_keep = ['Date'] + [col for col in column_list if col in df.columns]
filtered_with_date_df = df[columns_to_keep]


filtered_with_date_df['Date'] = pd.to_datetime(filtered_with_date_df['Date'])
start_date = pd.to_datetime("2018-03-31")
end_date = pd.to_datetime("2021-04-02")
filtered_df = filtered_with_date_df[(filtered_with_date_df['Date'] >= start_date) & (filtered_with_date_df['Date'] <= end_date)]
filtered_df.head()


df_cleaned = filtered_df.dropna(how='all', subset=filtered_df.columns.difference(['Date']))
rows_removed = len(filtered_df) - len(df_cleaned)
# print("ROWS REMOVED i.e. ALL VALUES MISSING EXCEPT DATE:", rows_removed)
df_cleaned.head()


df_fully_cleaned = df_cleaned.dropna(axis=1)
final_columns = df_fully_cleaned.columns.tolist()
if 'Date' in final_columns:
    final_columns.remove('Date')
print(final_columns)
df_fully_cleaned.head()


df_fully_cleaned['Date'] = pd.to_datetime(df_fully_cleaned['Date'])
df_fully_cleaned.set_index('Date', inplace=True)
pct_change_df = df_fully_cleaned.pct_change() 
pct_change_df = pct_change_df.iloc[1:] 
pct_change_df.head()
# pct_change_df.to_csv("gptwork.csv",index=False)



pct_change_df = pct_change_df.reset_index()  # This moves 'Date' from index to a regular column
pct_change_df.head()
# pct_change_df.to_csv("data1.csv",index=False)





# pct_change_df.to_csv("deletenow.csv",index=False)
# nan_counts = pct_change_df.isna().sum()
# print(nan_counts)
# columns_without_nans = df.columns[df.isna().sum() == 0].tolist()
# print(columns_without_nans)

# pct_change_df.dropna
# Out:
# ['CESC', 'CHOLAHLDNG', 'MUKANDLTD', 'THOMASCOOK', 'WELENT']
# C:\Users\meets\AppData\Local\Temp\ipykernel_9464\766037106.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_with_date_df['Date'] = pd.to_datetime(filtered_with_date_df['Date'])
#         Date      CESC  CHOLAHLDNG  MUKANDLTD  THOMASCOOK    WELENT
# 0 2018-04-03  0.017722    0.015723   0.039056   -0.032793  0.036030
# 1 2018-04-04 -0.027861   -0.004380   0.010180   -0.025609 -0.029199
# 2 2018-04-05  0.022518    0.000683   0.045736    0.019619  0.037175
# 3 2018-04-06  0.002002   -0.007124   0.017791    0.016155 -0.023460
# 4 2018-04-09  0.016983    0.005267  -0.018208    0.001429  0.019353

# %%
# PORTFOLIO WT CALCULATION

final_df = final_merged_df[final_merged_df['Stock Code'].isin([name.upper() for name in final_columns])]
final_df.head()

final_df['PORTFOLIO_WEIGHTS'] = final_df["ZSCORE_FINAL"]/final_df["ZSCORE_FINAL"].sum()
final_df.head()

final_df = final_df[["Stock Code","PORTFOLIO_WEIGHTS"]]
final_df.head(20)
# final_df.to_csv("data2.csv",index=False)
# Out:
#     Stock Code  PORTFOLIO_WEIGHTS
# 4         CESC           0.318962
# 5   CHOLAHLDNG           0.280453
# 10   MUKANDLTD           0.082928
# 13  THOMASCOOK           0.034672
# 14      WELENT           0.282986

# %%
#DIRECT COPYPASTE - NO EDIT


# Align columns: ensure weights match the columns in the return dataframe
returns_df = pct_change_df.copy()
weights_df = final_df.set_index("Stock Code")["PORTFOLIO_WEIGHTS"]

# Ensure only common stocks are used
common_stocks = returns_df.columns.intersection(weights_df.index)
returns_matrix = returns_df[common_stocks].copy()
weights_vector = weights_df.loc[common_stocks]

# Perform matrix multiplication (dot product) for each date
returns_df["Portfolio Return"] = returns_matrix.dot(weights_vector)

# Show a few results
final_portfolio = returns_df[["Date", "Portfolio Return"]]
final_portfolio.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date              744 non-null    datetime64[ns]
#  1   Portfolio Return  744 non-null    float64
# dtypes: datetime64[ns](1), float64(1)
# memory usage: 11.8 KB

# %%
#DIRECT COPYPASTE - NO EDIT

df2 = pd.read_csv("C:/Users/meets/AVENTUS_FACTOR-MODEL/SIMPLE STRATEGY/BENCHMARK/BSE500_PCTRETURNS_09-25.csv")
df2['BDP_Date'] = pd.to_datetime(df2['BDP_Date'])

final_portfolio_benchmark = pd.merge(final_portfolio, df2, how='inner', left_on='Date', right_on='BDP_Date')
final_portfolio_benchmark = final_portfolio_benchmark.drop('BDP_Date', axis=1)
final_portfolio_benchmark.set_index('Date', inplace=True)
final_portfolio_benchmark = final_portfolio_benchmark.rename(columns={'Portfolio Return':'Strategy'})
final_portfolio_benchmark.head()
# final_portfolio_benchmark.to_csv("s3l6b.csv")
# final_portfolio_benchmark.to_csv("final_portfolio_benchmarkQ.csv")
# Out:
#             Strategy  BDP_Close
# Date
# 2018-04-03  0.022360   0.005786
# 2018-04-04 -0.018422  -0.011007
# 2018-04-05  0.022367   0.018536
# 2018-04-06 -0.005963   0.002977
# 2018-04-09  0.010910   0.003774

# %%
import quantstats as qs

final_portfolio_benchmark.index = pd.to_datetime(final_portfolio_benchmark.index)

qs.reports.full(final_portfolio_benchmark['Strategy'],benchmark = final_portfolio_benchmark['BDP_Close'],mode="full")
# Out:
# <h4>Performance Metrics</h4>
#                            Benchmark    Strategy
# -------------------------  -----------  ----------
# Start Period               2018-04-03   2018-04-03
# End Period                 2021-04-01   2021-04-01
# Risk-Free Rate             0.0%         0.0%
# Time in Market             100.0%       100.0%
#
# Cumulative Return          38.98%       -10.69%
# CAGR﹪                     7.88%        -2.57%
#
# Sharpe                     0.64         0.01
# Prob. Sharpe Ratio         85.62%       50.73%
# Smart Sharpe               0.57         0.01
# Sortino                    0.85         0.01
# Smart Sortino              0.77         0.01
# Sortino/√2                 0.6          0.01
# Smart Sortino/√2           0.54         0.01
# Omega                      1.0          1.0
#
# Max Drawdown               -38.39%      -68.06%
# Longest DD Days            495          1039
# Volatility (ann.)          20.84%       28.66%
# R^2                        0.41         0.41
# Information Ratio          -0.04        -0.04
# Calmar                     0.21         -0.04
# Skew                       -1.56        -0.49
# Kurtosis                   18.85        5.86
#
# Expected Daily %           0.04%        -0.02%
# Expected Monthly %         0.89%        -0.31%
# Expected Yearly %          8.58%        -2.79%
# Kelly Criterion            4.79%        -8.52%
# Risk of Ruin               0.0%         0.0%
# Daily Value-at-Risk        -2.11%       -2.97%
# Expected Shortfall (cVaR)  -2.11%       -2.97%
#
# Max Consecutive Wins       10           10
# Max Consecutive Losses     9            8
# Gain/Pain Ratio            0.13         0.0
# Gain/Pain (1M)             0.63         0.01
#
# Payoff Ratio               0.83         0.92
# Profit Factor              1.13         1.0
# Common Sense Ratio         1.08         1.1
# CPC Index                  0.54         0.44
# Tail Ratio                 0.95         1.1
# Outlier Win Ratio          5.29         3.16
# Outlier Loss Ratio         4.57         3.4
#
# MTD                        1.35%        2.66%
# 3M                         8.56%        15.93%
# 6M                         33.77%       44.49%
# YTD                        8.56%        15.93%
# 1Y                         79.01%       139.01%
# 3Y (ann.)                  6.79%        -4.33%
# 5Y (ann.)                  7.88%        -2.57%
# 10Y (ann.)                 7.88%        -2.57%
# All-time (ann.)            7.88%        -2.57%
#
# Best Day                   7.78%        7.17%
# Worst Day                  -12.88%      -12.25%
# Best Month                 14.62%       31.75%
# Worst Month                -24.13%      -39.86%
# Best Year                  16.8%        15.93%
# Worst Year                 1.72%        -20.85%
#
# Avg. Drawdown              -3.4%        -6.61%
# Avg. Drawdown Days         37           89
# Recovery Factor            1.03         0.01
# Ulcer Index                0.1          0.37
# Serenity Index             0.28         0.0
#
# Avg. Up Month              5.64%        9.18%
# Avg. Down Month            -5.0%        -10.52%
# Win Days %                 56.72%       48.12%
# Win Month %                56.76%       54.05%
# Win Quarter %              69.23%       46.15%
# Win Year %                 100.0%       50.0%
#
# Beta                       -            0.89
# Alpha                      -            -0.12
# Correlation                -            64.39%
# Treynor Ratio              -            -12.07%
# None
# <h4 style="margin-bottom:20px">Worst 5 Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2018-05-29  2020-03-25  2021-04-01  1039    -68.063804        -65.391904
# 2  2018-05-02  2018-05-04  2018-05-04     3     -3.095833         -2.320667
# 3  2018-04-04  2018-04-04  2018-04-04     1     -1.842150               NaN
# 4  2018-04-20  2018-04-26  2018-04-27     8     -1.375162         -1.203937
# 5  2018-05-09  2018-05-09  2018-05-09     1     -1.051871               NaN
# <h4>Strategy Visualization</h4>
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# Cell In[22], line 5
#       1 import quantstats as qs
#       3 final_portfolio_benchmark.index = pd.to_datetime(final_portfolio_benchmark.index)
# ----> 5 qs.reports.full(final_portfolio_benchmark['Strategy'],benchmark = final_portfolio_benchmark['BDP_Close'],mode="full")
#
# File c:\Python310\lib\site-packages\quantstats\reports.py:628, in full(returns, benchmark, rf, grayscale, figsize, display, compounded, periods_per_year, match_dates, **kwargs)
#     625     print("\n\n")
#     626     print("[Strategy Visualization]\nvia Matplotlib")
# --> 628 plots(
#     629     returns=returns,
#     630     benchmark=benchmark,
#     631     grayscale=grayscale,
#     632     figsize=figsize,
#     633     mode="full",
#     634     periods_per_year=periods_per_year,
#     635     prepare_returns=False,
#     636     benchmark_title=benchmark_title,
#     637     strategy_title=strategy_title,
#     638     active=active,
#     639 )
#
# File c:\Python310\lib\site-packages\quantstats\reports.py:1329, in plots(returns, benchmark, grayscale, figsize, mode, compounded, periods_per_year, prepare_returns, match_dates, **kwargs)
#    1308     _plots.returns(
#    1309         returns,
#    1310         benchmark,
#    (...)
#    1316         prepare_returns=False,
#    1317     )
#    1319 _plots.yearly_returns(
#    1320     returns,
#    1321     benchmark,
#    (...)
#    1326     prepare_returns=False,
#    1327 )
# -> 1329 _plots.histogram(
#    1330     returns,
#    1331     benchmark,
#    1332     grayscale=grayscale,
#    1333     figsize=(figsize[0], figsize[0] * 0.5),
#    1334     show=True,
#    1335     ylabel='',
#    1336     prepare_returns=False,
#    1337 )
#    1339 small_fig_size = (figsize[0], figsize[0] * 0.35)
#    1340 if len(returns.columns) > 1:
#
# File c:\Python310\lib\site-packages\quantstats\_plotting\wrappers.py:658, in histogram(returns, benchmark, resample, fontname, grayscale, figsize, ylabel, subtitle, compounded, savefig, show, prepare_returns)
#     655 else:
#     656     title = ""
# --> 658 return _core.plot_histogram(
#     659     returns,
#     660     benchmark,
#     661     resample=resample,
#     662     grayscale=grayscale,
#     663     fontname=fontname,
#     664     title="Distribution of %sReturns" % title,
#     665     figsize=figsize,
#     666     ylabel=ylabel,
#     667     subtitle=subtitle,
#     668     compounded=compounded,
#     669     savefig=savefig,
#     670     show=show,
#     671 )
#
# File c:\Python310\lib\site-packages\quantstats\_plotting\core.py:500, in plot_histogram(returns, benchmark, resample, bins, fontname, grayscale, title, kde, figsize, ylabel, subtitle, compounded, savefig, show)
#     492     elif isinstance(returns, _pd.DataFrame):
#     493         combined_returns = (
#     494             benchmark.to_frame()
#     495             .join(returns)
#    (...)
#     498             .rename(columns={"level_1": "", 0: "Returns"})
#     499         )
# --> 500     x = _sns.histplot(
#     501         data=combined_returns,
#     502         x="Returns",
#     503         bins=bins,
#     504         alpha=alpha,
#     505         kde=kde,
#     506         stat="density",
#     507         hue="",
#     508         palette=pallete,
#     509         ax=ax,
#     510     )
#     512 else:
#     513     if isinstance(returns, _pd.Series):
#
# File c:\Python310\lib\site-packages\seaborn\distributions.py:1432, in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1421 estimate_kws = dict(
#    1422     stat=stat,
#    1423     bins=bins,
#    (...)
#    1427     cumulative=cumulative,
#    1428 )
#    1430 if p.univariate:
# -> 1432     p.plot_univariate_histogram(
#    1433         multiple=multiple,
#    1434         element=element,
#    1435         fill=fill,
#    1436         shrink=shrink,
#    1437         common_norm=common_norm,
#    1438         common_bins=common_bins,
#    1439         kde=kde,
#    1440         kde_kws=kde_kws,
#    1441         color=color,
#    1442         legend=legend,
#    1443         estimate_kws=estimate_kws,
#    1444         line_kws=line_kws,
#    1445         **kwargs,
#    1446     )
#    1448 else:
#    1450     p.plot_bivariate_histogram(
#    1451         common_bins=common_bins,
#    1452         common_norm=common_norm,
#    (...)
#    1462         **kwargs,
#    1463     )
#
# File c:\Python310\lib\site-packages\seaborn\distributions.py:430, in _DistributionPlotter.plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     427 histograms = {}
#     429 # Do pre-compute housekeeping related to multiple groups
# --> 430 all_data = self.comp_data.dropna()
#     431 all_weights = all_data.get("weights", None)
#     433 multiple_histograms = set(self.variables) - {"x", "y"}
#
# File c:\Python310\lib\site-packages\seaborn\_oldcore.py:1119, in VectorPlotter.comp_data(self)
#    1117 grouped = self.plot_data[var].groupby(self.converters[var], sort=False)
#    1118 for converter, orig in grouped:
# -> 1119     with pd.option_context('mode.use_inf_as_null', True):
#    1120         orig = orig.dropna()
#    1121         if var in self.var_levels:
#    1122             # TODO this should happen in some centralized location
#    1123             # it is similar to GH2419, but more complicated because
#    1124             # supporting `order` in categorical plots is tricky
#
# File c:\Python310\lib\site-packages\pandas\_config\config.py:480, in option_context.__enter__(self)
#     479 def __enter__(self) -> None:
# --> 480     self.undo = [(pat, _get_option(pat)) for pat, val in self.ops]
#     482     for pat, val in self.ops:
#     483         _set_option(pat, val, silent=True)
#
# File c:\Python310\lib\site-packages\pandas\_config\config.py:480, in <listcomp>(.0)
#     479 def __enter__(self) -> None:
# --> 480     self.undo = [(pat, _get_option(pat)) for pat, val in self.ops]
#     482     for pat, val in self.ops:
#     483         _set_option(pat, val, silent=True)
#
# File c:\Python310\lib\site-packages\pandas\_config\config.py:146, in _get_option(pat, silent)
#     145 def _get_option(pat: str, silent: bool = False) -> Any:
# --> 146     key = _get_single_key(pat, silent)
#     148     # walk the nested dict
#     149     root, k = _get_root(key)
#
# File c:\Python310\lib\site-packages\pandas\_config\config.py:132, in _get_single_key(pat, silent)
#     130     if not silent:
#     131         _warn_if_deprecated(pat)
# --> 132     raise OptionError(f"No such keys(s): {repr(pat)}")
#     133 if len(keys) > 1:
#     134     raise OptionError("Pattern matched multiple keys")
#
# OptionError: No such keys(s): 'mode.use_inf_as_null'
